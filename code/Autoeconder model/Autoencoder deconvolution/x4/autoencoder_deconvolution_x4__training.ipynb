# %%
pip uninstall opencv-python --yes
# Out:
# WARNING: Skipping opencv-python as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
# !wget data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# Out:
# --2022-06-11 00:29:12--  http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.178, 2001:67c:10ec:36c2::178
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip [following]
# --2022-06-11 00:29:13--  https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3530603713 (3.3G) [application/zip]
# Saving to: ‘DIV2K_train_HR.zip.1’
#
# DIV2K_train_HR.zip. 100%[===================>]   3.29G  22.7MB/s    in 2m 31s
#
# 2022-06-11 00:31:44 (22.3 MB/s) - ‘DIV2K_train_HR.zip.1’ saved [3530603713/3530603713]

# %%
# !wget data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip
# Out:
# --2022-06-11 00:32:22--  http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.178, 2001:67c:10ec:36c2::178
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip [following]
# --2022-06-11 00:32:22--  https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 448993893 (428M) [application/zip]
# Saving to: ‘DIV2K_valid_HR.zip.1’
#
# DIV2K_valid_HR.zip. 100%[===================>] 428.19M  26.1MB/s    in 18s
#
# 2022-06-11 00:32:40 (24.4 MB/s) - ‘DIV2K_valid_HR.zip.1’ saved [448993893/448993893]

# %%
from zipfile import ZipFile
zf = ZipFile('DIV2K_train_HR.zip', 'r')
zf.extractall('data/train_data') # zip all image in folder images 
zf.close()

# %%
from zipfile import ZipFile
zf = ZipFile('DIV2K_valid_HR.zip', 'r')
zf.extractall('data/train_data') # zip all image in folder images 
zf.close()

# %%
pip uninstall opencv-python --yes
# Out:
# WARNING: Skipping opencv-python as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall opencv-contrib-python --yes
# Out:
# WARNING: Skipping opencv-contrib-python as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/conda/envs/saturn/lib/python3.9/site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from opencv-python) (1.19.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python-headless
# Out:
# Collecting opencv-python-headless
#   Using cached opencv_python_headless-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (48.3 MB)
# Requirement already satisfied: numpy>=1.19.3 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from opencv-python-headless) (1.19.5)
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.6.0.66
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /opt/conda/envs/saturn/lib/python3.9/site-packages (2.4.1)
# Collecting numpy~=1.19.2
#   Using cached numpy-1.19.5-cp39-cp39-manylinux2010_x86_64.whl (14.9 MB)
# Requirement already satisfied: google-pasta~=0.2 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting tensorflow-estimator<2.5.0,>=2.4.0
#   Using cached tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
# Collecting gast==0.3.3
#   Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: termcolor~=1.1.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: wheel~=0.35 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorflow) (3.20.1)
# Collecting six~=1.15.0
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: h5py~=2.10.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorflow) (2.10.0)
# Collecting typing-extensions~=3.7.4
#   Using cached typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: tensorboard~=2.4 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorflow) (2.6.0)
# Collecting absl-py~=0.10
#   Using cached absl_py-0.15.0-py3-none-any.whl (132 kB)
# Collecting grpcio~=1.32.0
#   Using cached grpcio-1.32.0-cp39-cp39-linux_x86_64.whl
# Collecting wrapt~=1.12.1
#   Using cached wrapt-1.12.1-cp39-cp39-linux_x86_64.whl
# Requirement already satisfied: astunparse~=1.6.3 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (0.6.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (2.1.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (3.3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (59.8.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.2.7)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.4->tensorflow) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2022.5.18)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2.0.12)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (3.2.0)
# Installing collected packages: six, numpy, grpcio, absl-py, wrapt, typing-extensions, tensorflow-estimator, gast, flatbuffers
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.2
#     Uninstalling numpy-1.21.2:
#       Successfully uninstalled numpy-1.21.2
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.46.1
#     Uninstalling grpcio-1.46.1:
#       Successfully uninstalled grpcio-1.46.1
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.0.0
#     Uninstalling absl-py-1.0.0:
#       Successfully uninstalled absl-py-1.0.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.14.1
#     Uninstalling wrapt-1.14.1:
#       Successfully uninstalled wrapt-1.14.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.2.0
#     Uninstalling typing-extensions-4.2.0:
#       Successfully uninstalled typing-extensions-4.2.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.6.0
#     Uninstalling tensorflow-estimator-2.6.0:
#       Successfully uninstalled tensorflow-estimator-2.6.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bokeh 2.4.2 requires typing-extensions>=3.10.0, but you have typing-extensions 3.7.4.3 which is incompatible.
# aioitertools 0.10.0 requires typing_extensions>=4.0; python_version < "3.10", but you have typing-extensions 3.7.4.3 which is incompatible.
# Successfully installed absl-py-0.15.0 flatbuffers-1.12 gast-0.3.3 grpcio-1.32.0 numpy-1.19.5 six-1.15.0 tensorflow-estimator-2.4.0 typing-extensions-3.7.4.3 wrapt-1.12.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/conda/envs/saturn/lib/python3.9/site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.19.3 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from opencv-python) (1.19.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall opencv-python-headless --yes
# Out:
# Found existing installation: opencv-python-headless 4.5.3.56
# Uninstalling opencv-python-headless-4.5.3.56:
#   Successfully uninstalled opencv-python-headless-4.5.3.56
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall opencv-python-headless --yes
# Out:
# WARNING: Skipping opencv-python-headless as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall opencv-python
# Out:
# WARNING: Skipping opencv-python as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.9 MB)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from opencv-python) (1.19.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.6.0.66
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-contrib-python
# Out:
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67.1 MB)
#      |████████████████████████████████| 67.1 MB 3.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.14.5 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from opencv-contrib-python) (1.19.5)
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-4.6.0.66
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/conda/envs/saturn/lib/python3.9/site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from opencv-python) (1.19.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.layers import Conv2DTranspose, UpSampling2D, add
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
import matplotlib.pyplot as plt
from scipy import ndimage, misc
from matplotlib import pyplot
import tensorflow as tf
import numpy as np
np.random.seed(0)
import re
import os
import cv2
# Out:
# 2022-06-11 00:54:04.586210: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
def lowResolution(path,sizeHigh,size):
    names = sorted(os.listdir(path))
    allLowImages = []
    for name in names:
        fpath = path + name
        img = cv2.imread(fpath, cv2.IMREAD_COLOR)
        image=cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
        
        
        image = cv2.resize(image,(int(sizeHigh),int(sizeHigh)),cv2.INTER_CUBIC) 
        image = cv2.resize(image,(int(size),int(size)),cv2.INTER_CUBIC) 
        lowimage=image[:, :, :].astype(float) / 255 
        
        allLowImages.append(lowimage) 
    allLowImages = np.array(allLowImages)
    return allLowImages

# %%
def highResolution(path,size):
    names = sorted(os.listdir(path))
    allHighimages = []
    for name in names:
        fpath = path + name
        img = cv2.imread(fpath, cv2.IMREAD_COLOR)
        image=cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #change bgr to rgb
        
        highimage = cv2.resize(image,(size,size),cv2.INTER_CUBIC) 
        highimage=highimage[:, :, :].astype(float) / 255 
        
        allHighimages.append(highimage) 
    allHighimages = np.array(allHighimages)
    return allHighimages

# %%
input_img = Input(shape=(None, None, 3))
l1 = Conv2D(64, (3, 3), padding = 'same', activation = 'relu', 
            activity_regularizer = regularizers.l1(10e-10))(input_img)

l2 = Conv2D(64, (3, 3), padding = 'same', activation = 'relu', 
            activity_regularizer = regularizers.l1(10e-10))(l1)

l3 = MaxPooling2D(padding = 'same')(l2)   
l3 = Dropout(0.3)(l3)

l4 = Conv2D(128, (3, 3),  padding = 'same', activation = 'relu', 
            activity_regularizer = regularizers.l1(10e-10))(l3)

l5 = Conv2D(128, (3, 3), padding = 'same', activation = 'relu', 
            activity_regularizer = regularizers.l1(10e-10))(l4)

l6 = MaxPooling2D(padding = 'same')(l5) #2

l7 = Conv2D(256, (3, 3), padding = 'same', activation = 'relu', 
            activity_regularizer = regularizers.l1(10e-10))(l6)
l8 = Conv2DTranspose(256, (2,2), strides=(2,2))(l7)

l9 = Conv2D(128, (3, 3), padding = 'same', activation = 'relu',
            activity_regularizer = regularizers.l1(10e-10))(l8)

l10 = Conv2D(128, (3, 3), padding = 'same', activation = 'relu',
             activity_regularizer = regularizers.l1(10e-10))(l9)     # 2  /   2 

l11 = add([l5, l10])
l12 = Conv2DTranspose(128, (2,2), strides=(2,2))(l11)

l13 = Conv2D(64, (3, 3), padding = 'same', activation = 'relu',
             activity_regularizer = regularizers.l1(10e-10))(l12)

l14 = Conv2D(64, (3, 3), padding = 'same', activation = 'relu',
             activity_regularizer = regularizers.l1(10e-10))(l13)

l15 = add([l14, l2])
postUpsampling= Conv2DTranspose(64, (4,4), strides=(4,4))(l15)

decoded = Conv2D(3, (3, 3), padding = 'same', 
                 activation = 'relu', activity_regularizer = regularizers.l1(10e-10))(postUpsampling)


autoencoder = Model(input_img, decoded)

# %%
autoencoder.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 6 1792        input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 6 36928       conv2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 6 0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, None, 6 0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 1 73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 1 147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 1 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 2 295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, None, None, 2 262400      conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 1 295040      conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 1 147584      conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 1 0           conv2d_13[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, None, None, 1 65664       add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 6 73792       conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 6 36928       conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 6 0           conv2d_18[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, None, None, 6 65600       add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 3 1731        conv2d_transpose_5[0][0]
# ==================================================================================================
# Total params: 1,504,067
# Trainable params: 1,504,067
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
autoencoder.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics='accuracy')

# %%
x_train_low=lowResolution("./data/train_data/DIV2K_train_HR/",400,100)

# %%
x_train_high = highResolution("./data/train_data/DIV2K_train_HR/",400)

# %%
print(x_train_low.shape)
# Out:
# (900, 100, 100, 3)

# %%
print(x_train_high.shape)
# Out:
# (900, 400, 400, 3)

# %%
plt.figure(figsize = (100, 100))
i = 1
ax = plt.subplot(10, 10, i)
plt.imshow(x_train_low[5])
plt.title("the low resolution")
i += 1
ax = plt.subplot(10, 10, i)
plt.imshow(x_train_high[5])
plt.title("high resolution ")
# Out:
# Text(0.5, 1.0, 'high resolution ')

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=10,restore_best_weights=True)

# %%
history=autoencoder.fit(x_train_low, x_train_high,epochs=120,batch_size=10,shuffle=True, callbacks=[callback],validation_split=0.2)
# Out:
# 2022-06-11 00:58:10.100374: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-06-11 00:58:10.129638: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2499995000 Hz
# Epoch 1/120
# 2022-06-11 00:58:11.486105: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-06-11 00:58:13.938526: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 
120
# 72/72 [==============================] - 10s 144ms/step - loss: 0.0091 - accuracy: 0.8729 - val_loss: 0.0086 - val_accuracy: 0.8772
# Epoch 25/120
# 72/72 [==============================] - 10s 144ms/step - loss: 0.0088 - accuracy: 0.8816 - val_loss: 0.0086 - val_accuracy: 0.8677
# Epoch 26/120
# 72/72 [==============================] - 10s 144ms/step - loss: 0.0092 - accuracy: 0.8748 - val_loss: 0.0086 - val_accuracy: 0.8743
# Epoch 27/120
# 72/72 [==============================] - 10s 144ms/step - loss: 0.0090 - accuracy: 0.8792 - val_loss: 0.0086 - val_accuracy: 0.8313
# Epoch 28/120
# 72/72 [==============================] - 10s 145ms/step - loss: 0.0089 - accuracy: 0.8676 - val_loss: 0.0087 - val_accuracy: 0.8558
# Epoch 29/120
# 72/72 [==============================] - 10s 145ms/step - loss: 0.0090 - accuracy: 0.8744 - val_loss: 0.0086 - val_accuracy: 0.8631
# Epoch 30/120
# 72/72 [==============================] - 10s 145ms/step - loss: 0.0089 - accuracy: 0.8828 - val_loss: 0.0086 - val_accuracy: 0.8681
# Epoch 31/120
# 72/72 [==============================] - 10s 145ms/step - loss: 0.0089 - accuracy: 0.8726 - val_loss: 0.0086 - val_accuracy: 0.8705
# Epoch 32/120
# 72/72 [==============================] - 10s 145ms/step - loss: 0.0094 - accuracy: 0.8743 - val_loss: 0.0086 - val_accuracy: 0.8768
# Epoch 33/120
# 72/72 [==============================] - 10s 146ms/step - loss: 0.0089 - accuracy: 0.8679 - val_loss: 0.0089 - val_accuracy: 0.8304
# Epoch 34/120
# 72/72 [==============================] - 10s 146ms/step - loss: 0.0095 - accuracy: 0.8472 - val_loss: 0.0086 - val_accuracy: 0.8626
# Epoch 35/120
# 72/72 [==============================] - 11s 147ms/step - loss: 0.0088 - accuracy: 0.8745 - val_loss: 0.0087 - val_accuracy: 0.8486
# Epoch 36/120
# 72/72 [==============================] - 11s 147ms/step - loss: 0.0090 - accuracy: 0.8732 - val_loss: 0.0085 - val_accuracy: 0.8734
# Epoch 37/120
# 72/72 [==============================] - 11s 148ms/step - loss: 0.0094 - accuracy: 0.8846 - val_loss: 0.0085 - val_accuracy: 0.8771
# Epoch 38/120
# 72/72 [==============================] - 11s 149ms/step - loss: 0.0090 - accuracy: 0.8789 - val_loss: 0.0086 - val_accuracy: 0.8648
# Epoch 39/120
# 72/72 [==============================] - 11s 149ms/step - loss: 0.0092 - accuracy: 0.8703 - val_loss: 0.0086 - val_accuracy: 0.8446
# Epoch 40/120
# 72/72 [==============================] - 11s 150ms/step - loss: 0.0091 - accuracy: 0.8779 - val_loss: 0.0085 - val_accuracy: 0.8750
# Epoch 41/120
# 72/72 [==============================] - 11s 151ms/step - loss: 0.0095 - accuracy: 0.8823 - val_loss: 0.0085 - val_accuracy: 0.8692
# Epoch 42/120
# 72/72 [==============================] - 11s 152ms/step - loss: 0.0091 - accuracy: 0.8772 - val_loss: 0.0085 - val_accuracy: 0.8648
# Epoch 43/120
# 72/72 [==============================] - 11s 153ms/step - loss: 0.0089 - accuracy: 0.8765 - val_loss: 0.0086 - val_accuracy: 0.8425
# Epoch 44/120
# 72/72 [==============================] - 11s 153ms/step - loss: 0.0089 - accuracy: 0.8706 - val_loss: 0.0085 - val_accuracy: 0.8662
# Epoch 45/120
# 72/72 [==============================] - 11s 154ms/step - loss: 0.0090 - accuracy: 0.8764 - val_loss: 0.0085 - val_accuracy: 0.8567
# Epoch 46/120
# 72/72 [==============================] - 11s 154ms/step - loss: 0.0084 - accuracy: 0.8773 - val_loss: 0.0086 - val_accuracy: 0.8535
# Epoch 47/120
# 72/72 [==============================] - 11s 155ms/step - loss: 0.0091 - accuracy: 0.8780 - val_loss: 0.0085 - val_accuracy: 0.8653
# Epoch 48/120
# 72/72 [==============================] - 11s 155ms/step - loss: 0.0091 - accuracy: 0.8844 - val_loss: 0.0085 - val_accuracy: 0.8723
# Epoch 49/120
# 72/72 [==============================] - 11s 156ms/step - loss: 0.
120
# 72/72 [==============================] - 11s 155ms/step - loss: 0.0085 - accuracy: 0.8861 - val_loss: 0.0083 - val_accuracy: 0.8830
# Epoch 104/120
# 72/72 [==============================] - 11s 156ms/step - loss: 0.0086 - accuracy: 0.8932 - val_loss: 0.0083 - val_accuracy: 0.8853
# Epoch 105/120
# 72/72 [==============================] - 11s 156ms/step - loss: 0.0088 - accuracy: 0.8854 - val_loss: 0.0083 - val_accuracy: 0.8658
# Epoch 106/120
# 72/72 [==============================] - 11s 156ms/step - loss: 0.0089 - accuracy: 0.8728 - val_loss: 0.0084 - val_accuracy: 0.8482
# Epoch 107/120
# 72/72 [==============================] - 11s 156ms/step - loss: 0.0089 - accuracy: 0.8873 - val_loss: 0.0083 - val_accuracy: 0.8556
# Epoch 108/120
# 72/72 [==============================] - 11s 156ms/step - loss: 0.0088 - accuracy: 0.8857 - val_loss: 0.0084 - val_accuracy: 0.8778
# Epoch 109/120
# 72/72 [==============================] - 11s 156ms/step - loss: 0.0091 - accuracy: 0.8822 - val_loss: 0.0083 - val_accuracy: 0.8670
# Epoch 110/120
# 72/72 [==============================] - 11s 156ms/step - loss: 0.0091 - accuracy: 0.8810 - val_loss: 0.0083 - val_accuracy: 0.8780
# Epoch 111/120
# 72/72 [==============================] - 11s 155ms/step - loss: 0.0086 - accuracy: 0.8895 - val_loss: 0.0083 - val_accuracy: 0.8755
# Epoch 112/120
# 72/72 [==============================] - 11s 155ms/step - loss: 0.0090 - accuracy: 0.8835 - val_loss: 0.0083 - val_accuracy: 0.8745
# Epoch 113/120
# 72/72 [==============================] - 11s 155ms/step - loss: 0.0086 - accuracy: 0.8889 - val_loss: 0.0083 - val_accuracy: 0.8817
# Epoch 114/120
# 72/72 [==============================] - 11s 155ms/step - loss: 0.0090 - accuracy: 0.8843 - val_loss: 0.0084 - val_accuracy: 0.8716
# Epoch 115/120
# 72/72 [==============================] - 11s 156ms/step - loss: 0.0089 - accuracy: 0.8718 - val_loss: 0.0084 - val_accuracy: 0.8861
# Epoch 116/120
# 72/72 [==============================] - 11s 156ms/step - loss: 0.0089 - accuracy: 0.8771 - val_loss: 0.0083 - val_accuracy: 0.8805
# Epoch 117/120
# 72/72 [==============================] - 11s 155ms/step - loss: 0.0086 - accuracy: 0.8777 - val_loss: 0.0083 - val_accuracy: 0.8629
# Epoch 118/120
# 72/72 [==============================] - 11s 155ms/step - loss: 0.0089 - accuracy: 0.8843 - val_loss: 0.0083 - val_accuracy: 0.8844
# Epoch 119/120
# 72/72 [==============================] - 11s 155ms/step - loss: 0.0089 - accuracy: 0.8873 - val_loss: 0.0083 - val_accuracy: 0.8713
# Epoch 120/120
# 72/72 [==============================] - 11s 155ms/step - loss: 0.0088 - accuracy: 0.8889 - val_loss: 0.0085 - val_accuracy: 0.8818

# %%
loss=history.history["loss"]
val_loss=history.history["val_loss"]
epochs=range(1,len(loss)+1)
plt.plot(epochs,loss,'y',label="training loss")
plt.plot(epochs,val_loss,'r',label="validation loss")
plt.title("training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
acc=history.history["accuracy"]
val_acc=history.history["val_accuracy"]
epochs=range(1,len(loss)+1)
plt.plot(epochs,acc,'y',label="training acc")
plt.plot(epochs,val_acc,'r',label="validation acc")
plt.title("training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
print(history.history)
# Out:
# {'loss': [0.09152814000844955, 0.012626800686120987, 0.01025186013430357, 0.009765511378645897, 0.009591414593160152, 0.009488915093243122, 0.00940287671983242, 0.009340534918010235, 0.009324586018919945, 0.009286106564104557, 0.009261813946068287, 0.009241939522325993, 0.009232304990291595, 0.009287964552640915, 0.009195868857204914, 0.00917381513863802, 0.00915939174592495, 0.00915107037872076, 0.00913352333009243, 0.009134883061051369, 0.009133978746831417, 0.009180496446788311, 0.009108195081353188, 0.009085646830499172, 0.009076916612684727, 0.009069073013961315, 0.009088174439966679, 0.009063785895705223, 0.009065249934792519, 0.009044239297509193, 0.00904068909585476, 0.00903722271323204, 0.009146898053586483, 0.00910470262169838, 0.009024