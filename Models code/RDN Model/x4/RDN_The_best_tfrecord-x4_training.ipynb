# %%
pip install tqdm
# Out:
# Collecting tqdm
#   Using cached tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.64.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /opt/conda/envs/saturn/lib/python3.9/site-packages (2.4.1)
# Collecting wrapt~=1.12.1
#   Using cached wrapt-1.12.1-cp39-cp39-linux_x86_64.whl
# Collecting gast==0.3.3
#   Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting numpy~=1.19.2
#   Using cached numpy-1.19.5-cp39-cp39-manylinux2010_x86_64.whl (14.9 MB)
# Collecting absl-py~=0.10
#   Using cached absl_py-0.15.0-py3-none-any.whl (132 kB)
# Requirement already satisfied: opt-einsum~=3.3.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Collecting six~=1.15.0
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: google-pasta~=0.2 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Collecting typing-extensions~=3.7.4
#   Using cached typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: wheel~=0.35 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: termcolor~=1.1.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorflow) (1.1.0)
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorflow) (1.1.2)
# Collecting grpcio~=1.32.0
#   Using cached grpcio-1.32.0-cp39-cp39-linux_x86_64.whl
# Requirement already satisfied: astunparse~=1.6.3 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: h5py~=2.10.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorflow) (2.10.0)
# Collecting tensorflow-estimator<2.5.0,>=2.4.0
#   Using cached tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorflow) (3.20.1)
# Requirement already satisfied: tensorboard~=2.4 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (0.6.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (2.1.2)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (59.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (2.27.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (3.3.7)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.4->tensorflow) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2022.5.18)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2.0.12)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (3.2.0)
# Installing collected packages: six, numpy, grpcio, absl-py, wrapt, typing-extensions, tensorflow-estimator, gast, flatbuffers
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.2
#     Uninstalling numpy-1.21.2:
#       Successfully uninstalled numpy-1.21.2
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.46.1
#     Uninstalling grpcio-1.46.1:
#       Successfully uninstalled grpcio-1.46.1
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.0.0
#     Uninstalling absl-py-1.0.0:
#       Successfully uninstalled absl-py-1.0.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.14.1
#     Uninstalling wrapt-1.14.1:
#       Successfully uninstalled wrapt-1.14.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.2.0
#     Uninstalling typing-extensions-4.2.0:
#       Successfully uninstalled typing-extensions-4.2.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.6.0
#     Uninstalling tensorflow-estimator-2.6.0:
#       Successfully uninstalled tensorflow-estimator-2.6.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bokeh 2.4.2 requires typing-extensions>=3.10.0, but you have typing-extensions 3.7.4.3 which is incompatible.
# aioitertools 0.10.0 requires typing_extensions>=4.0; python_version < "3.10", but you have typing-extensions 3.7.4.3 which is incompatible.
# Successfully installed absl-py-0.15.0 flatbuffers-1.12 gast-0.3.3 grpcio-1.32.0 numpy-1.19.5 six-1.15.0 tensorflow-estimator-2.4.0 typing-extensions-3.7.4.3 wrapt-1.12.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.9 MB)
# Requirement already satisfied: numpy>=1.14.5 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from opencv-python) (1.19.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.6.0.66
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python-headless
# Out:
# Collecting opencv-python-headless
#   Using cached opencv_python_headless-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (48.3 MB)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/envs/saturn/lib/python3.9/site-packages (from opencv-python-headless) (1.19.5)
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.6.0.66
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from tensorflow.keras.initializers import RandomUniform
from tensorflow.keras.layers import concatenate, Input, Activation, Add, Conv2D, Lambda, UpSampling2D
from tensorflow.keras.models import Model
import os
from absl import app, flags, logging
from absl.flags import FLAGS
import os
import cv2
import pathlib
import numpy as np
import tensorflow as tf
import functools
from tensorflow.keras.layers import Dense, Flatten, Input, Conv2D, LeakyReLU
from tensorflow.keras import Model
from absl import app, flags, logging
from absl.flags import FLAGS
import os
import tqdm
import glob
import random
import tensorflow as tf

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1
# 2022-06-22 21:28:26.890522: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-06-22 21:28:26.891508: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-06-22 21:28:26.982411: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-22 21:28:26.983071: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2022-06-22 21:28:26.983117: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-22 21:28:26.985167: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-06-22 21:28:26.985235: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-06-22 21:28:26.986912: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-06-22 21:28:26.987235: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-06-22 21:28:26.989116: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-06-22 21:28:26.990184: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-06-22 21:28:26.994184: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-06-22 21:28:26.994320: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-22 21:28:26.994916: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-22 21:28:26.995428: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0

# %%
def _bytes_feature(value):
    """Returns a bytes_list from a string / byte."""
    if isinstance(value, type(tf.constant(0))):
        value = value.numpy()
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))



def _float_feature(value):
    """Returns a float_list from a float / double."""
    return tf.train.Feature(float_list=tf.train.FloatList(value=[value]))


def _int64_feature(value):
    """Returns an int64_list from a bool / enum / int / uint."""
    return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))


def make_example_bin(img_name, hr_img_str, lr_img_str):
    # Create a dictionary with features that may be relevant (binary).
    feature = {'image/img_name': _bytes_feature(img_name),
               'image/hr_encoded': _bytes_feature(hr_img_str),
               'image/lr_encoded': _bytes_feature(lr_img_str)}

    return tf.train.Example(features=tf.train.Features(feature=feature))


def make_example(img_name, hr_img_path, lr_img_path):
    # Create a dictionary with features that may be relevant.
    feature = {'image/img_name': _bytes_feature(img_name),
               'image/hr_img_path': _bytes_feature(hr_img_path),
               'image/lr_img_path': _bytes_feature(lr_img_path)}

    return tf.train.Example(features=tf.train.Features(feature=feature))


def MakeTfrecord(hr_dataset_path,lr_dataset_path,output_path,is_binary):

    if not os.path.isdir(hr_dataset_path):
        logging.info('Please define valid dataset path.')
    else:
        logging.info('Loading {}'.format(hr_dataset_path))

    samples = []
    logging.info('Reading data list...')
    
    for hr_img_path in glob.glob(os.path.join(hr_dataset_path, '*.png')):
        img_name = os.path.basename(hr_img_path).replace('.png', '')
        lr_img_path = os.path.join(lr_dataset_path, img_name + 'x4.png')
        samples.append((img_name, hr_img_path, lr_img_path))
    random.shuffle(samples)

    if os.path.exists(output_path):
        logging.info('{:s} already exists. Exit...'.format(output_path))
        exit(1)

    logging.info('Writing {} sample to tfrecord file...'.format(len(samples)))
    with tf.io.TFRecordWriter(output_path) as writer:
        for img_name, hr_img_path, lr_img_path in tqdm.tqdm(samples):
            if is_binary:
                hr_img_str = open(hr_img_path, 'rb').read()
                lr_img_str = open(lr_img_path, 'rb').read()
                tf_example = make_example_bin(img_name=str.encode(img_name), hr_img_str=hr_img_str,lr_img_str=lr_img_str)
            else:
                tf_example = make_example(img_name=str.encode(img_name),
                                          hr_img_path=str.encode(hr_img_path),lr_img_path=str.encode(lr_img_path))
            writer.write(tf_example.SerializeToString())

# %% [markdown]
# # TFrecord train data

# %%
train_hr_dataset_path='./data/DIV2K_train_HR/' # 'path to high resolution dataset'
train_lr_dataset_path='./data/DIV2K_train_LR_bicubic/X4/'#'path to low resolution dataset')
train_output_path='./data/DIV2K720_sub_bin_x4.tfrecord'#'path to ouput tfrecord')
is_binary=True #'whether save images as binary files'' or load them on the fly.')
MakeTfrecord(train_hr_dataset_path,train_lr_dataset_path,train_output_path,is_binary)
# Out:
#   0%|          | 0/720 [00:00<?, ?it/s]2022-06-22 21:28:34.273157: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-22 21:28:34.273438: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-06-22 21:28:34.273639: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-22 21:28:34.274218: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2022-06-22 21:28:34.274250: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-22 21:28:34.274293: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-06-22 21:28:34.274308: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-06-22 21:28:34.274321: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-06-22 21:28:34.274335: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-06-22 21:28:34.274348: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-06-22 21:28:34.274361: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-06-22 21:28:34.274375: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-06-22 21:28:34.274452: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-22 21:28:34.275014: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-22 21:28:34.275524: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-06-22 21:28:34.275560: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-22 21:28:34.943182: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-06-22 21:28:34.943223: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-06-22 21:28:34.943233: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-06-22 21:28:34.943476: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-22 21:28:34.944100: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-22 21:28:34.944695: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-22 21:28:34.945211: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13971 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5)
# 100%|██████████| 720/720 [00:42<00:00, 17.01it/s]

# %% [markdown]
# # TFrecord validation data

# %%
train_hr_dataset_path='./data/DIV2K_valid_HR/' # 'path to high resolution dataset'
train_lr_dataset_path='./data/DIV2K_valid_LR_bicubic/X4/'#'path to low resolution dataset')
train_output_path='./data/DIV2K180_sub_bin_x4.tfrecord'#'path to ouput tfrecord')
is_binary=True #'whether save images as binary files'' or load them on the fly.')
MakeTfrecord(train_hr_dataset_path,train_lr_dataset_path,train_output_path,is_binary)
# Out:
# 100%|██████████| 180/180 [00:10<00:00, 17.82it/s]

# %%
def load_dataset(pathTf,key, shuffle=True, buffer_size=32):
    """load dataset"""
    dataset_cfg = pathTf
    logging.info("load {} from {}".format(key, pathTf))
    dataset = load_tfrecord_dataset(
        tfrecord_name= pathTf, batch_size= 10 ,gt_size= 256 ,scale= 4, shuffle=shuffle , using_bin= True , using_flip= True,using_rot=True , buffer_size=buffer_size)
    
    return dataset

# %%
def load_tfrecord_dataset(tfrecord_name, batch_size, gt_size,scale, using_bin=False, using_flip=False, using_rot=False, shuffle=True, buffer_size=10240):
    """load dataset from tfrecord"""
    raw_dataset = tf.data.TFRecordDataset(tfrecord_name)
    raw_dataset = raw_dataset.repeat()
    if shuffle:
        raw_dataset = raw_dataset.shuffle(buffer_size=buffer_size)
    dataset = raw_dataset.map(_parse_tfrecord(gt_size, scale, using_bin, using_flip, using_rot),num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch( buffer_size=tf.data.experimental.AUTOTUNE)
    return dataset

# %%
def _parse_tfrecord(gt_size, scale, using_bin, using_flip, using_rot):
    def parse_tfrecord(tfrecord):
        if using_bin:
            features = {
                'image/img_name': tf.io.FixedLenFeature([], tf.string),
                'image/hr_encoded': tf.io.FixedLenFeature([], tf.string),
                'image/lr_encoded': tf.io.FixedLenFeature([], tf.string)}
            x = tf.io.parse_single_example(tfrecord, features)
            lr_img = tf.image.decode_png(x['image/lr_encoded'], channels=3)
            hr_img = tf.image.decode_png(x['image/hr_encoded'], channels=3)
        else:
            features = {
                'image/img_name': tf.io.FixedLenFeature([], tf.string),
                'image/hr_img_path': tf.io.FixedLenFeature([], tf.string),
                'image/lr_img_path': tf.io.FixedLenFeature([], tf.string)}
            x = tf.io.parse_single_example(tfrecord, features)
            hr_image_encoded = tf.io.read_file(x['image/hr_img_path'])
            lr_image_encoded = tf.io.read_file(x['image/lr_img_path'])
            lr_img = tf.image.decode_png(lr_image_encoded, channels=3)
            hr_img = tf.image.decode_png(hr_image_encoded, channels=3)

        lr_img, hr_img = _transform_images(gt_size, scale, using_flip, using_rot)(lr_img, hr_img)
        
        
        return lr_img, hr_img
    return parse_tfrecord

# %%
def _transform_images(gt_size, scale, using_flip, using_rot):
    def transform_images(lr_img, hr_img):
        lr_img_shape = tf.shape(lr_img)
        hr_img_shape = tf.shape(hr_img)
        gt_shape = (gt_size, gt_size, tf.shape(hr_img)[-1])
        lr_size = int(gt_size / scale)
        lr_shape = (lr_size, lr_size, tf.shape(lr_img)[-1])

        tf.Assert(
            tf.reduce_all(hr_img_shape >= gt_shape),
            ["Need hr_image.shape >= gt_size, got ", hr_img_shape, gt_shape])
        tf.Assert(
            tf.reduce_all(hr_img_shape[:-1] == lr_img_shape[:-1] * scale),
            ["Need hr_image.shape == lr_image.shape * scale, got ",
             hr_img_shape[:-1], lr_img_shape[:-1] * scale])
        tf.Assert(
            tf.reduce_all(hr_img_shape[-1] == lr_img_shape[-1]),
            ["Need hr_image.shape[-1] == lr_image.shape[-1]], got ",
             hr_img_shape[-1], lr_img_shape[-1]])

        # randomly crop
        limit = lr_img_shape - lr_shape + 1
        offset = tf.random.uniform(tf.shape(lr_img_shape), dtype=tf.int32,
                                   maxval=tf.int32.max) % limit
        lr_img = tf.slice(lr_img, offset, lr_shape)
        hr_img = tf.slice(hr_img, offset * scale, gt_shape)

        # randomly left-right flip
        if using_flip:
            flip_case = tf.random.uniform([1], 0, 2, dtype=tf.int32)
            def flip_func(): return (tf.image.flip_left_right(lr_img),
                                     tf.image.flip_left_right(hr_img))
            lr_img, hr_img = tf.case(
                [(tf.equal(flip_case, 0), flip_func)],
                default=lambda: (lr_img, hr_img))

        # randomly rotation
        if using_rot:
            rot_case = tf.random.uniform([1], 0, 4, dtype=tf.int32)
            def rot90_func(): return (tf.image.rot90(lr_img, k=1),
                                      tf.image.rot90(hr_img, k=1))
            def rot180_func(): return (tf.image.rot90(lr_img, k=2),
                                       tf.image.rot90(hr_img, k=2))
            def rot270_func(): return (tf.image.rot90(lr_img, k=3),
                                       tf.image.rot90(hr_img, k=3))
            lr_img, hr_img = tf.case(
                [(tf.equal(rot_case, 0), rot90_func),
                 (tf.equal(rot_case, 1), rot180_func),
                 (tf.equal(rot_case, 2), rot270_func)],
                default=lambda: (lr_img, hr_img))

        # scale to [0, 1]
        lr_img = lr_img / 255
        hr_img = hr_img / 255
        
        return lr_img, hr_img
    return transform_images

# %%
train_dataset  =  load_dataset('./data/DIV2K720_sub_bin_x4.tfrecord','train_dataset', shuffle=False)

# %%
valid_dataset  =  load_dataset('./data/DIV2K180_sub_bin_x4.tfrecord','valid_dataset', shuffle=False)

# %%
print(train_dataset)
# Out:
# <PrefetchDataset shapes: ((10, 64, 64, None), (10, 256, 256, None)), types: (tf.float32, tf.float32)>

# %%
print(valid_dataset)
# Out:
# <PrefetchDataset shapes: ((10, 64, 64, None), (10, 256, 256, None)), types: (tf.float32, tf.float32)>

# %%
 def _pixel_shuffle(input_layer):
        """ PixelShuffle implementation of the upscaling layer. """
        initializer = RandomUniform( minval=-0.05, maxval=0.05, seed=None)
        x = Conv2D(
            3 * 4 ** 2,
            kernel_size=3,
            padding='same',
            name='UPN3',
            kernel_initializer=initializer,
        )(input_layer)
        return Lambda(
            lambda x: tf.nn.depth_to_space(x, block_size=4, data_format='NHWC'),
            name='PixelShuffle',
        )(x)

# %%
def _upsampling_block( input_layer):
    """ Upsampling block for old weights. """
    initializer = RandomUniform( minval=-0.05, maxval=0.05, seed=None)
    scale=4
    x = Conv2D(
        3 * scale ** 2,
        kernel_size=3,
        padding='same',
        name='UPN3',
        kernel_initializer=initializer,
    )(input_layer)
    return UpSampling2D(size=scale, name='UPsample')(x)

# %%
def _UPN(input_layer):
    upscaling='shuffle'
    """ Upscaling layers. With old weights use _upsampling_block instead of _pixel_shuffle. """
    initializer = RandomUniform( minval=-0.05, maxval=0.05, seed=None)
    x = Conv2D(
        64,
        kernel_size=5,
        strides=1,
        padding='same',
        name='UPN1',
        kernel_initializer=initializer,
    )(input_layer)
    x = Activation('relu', name='UPN1_Relu')(x)
    x = Conv2D(
        32, kernel_size=3, padding='same', name='UPN2', kernel_initializer=initializer
    )(x)
    x = Activation('relu', name='UPN2_Relu')(x)
    if upscaling == 'shuffle':
        return _pixel_shuffle(x)
    elif upscaling == 'ups':
        return _upsampling_block(x)
    else:
        raise ValueError('Invalid choice of upscaling layer.')

# %%
def _RDBs(input_layer):
        """RDBs blocks.
        Args:
            input_layer: input layer to the RDB blocks (e.g. the second convolutional layer F_0).
        Returns:
            concatenation of RDBs output feature maps with G0 feature maps.
        """
        initializer = RandomUniform( minval=-0.05, maxval=0.05, seed=None)
        rdb_concat = list()
        rdb_in = input_layer
        for d in range(1, 20+ 1):
            x = rdb_in
            for c in range(1, 6 + 1):
                F_dc = Conv2D(
                    64,
                    kernel_size=3,
                    padding='same',
                    kernel_initializer=initializer,
                    name='F_%d_%d' % (d, c),
                )(x)
                F_dc = Activation('relu', name='F_%d_%d_Relu' % (d, c))(F_dc)
                # concatenate input and output of ConvRelu block
                # x = [input_layer,F_11(input_layer),F_12([input_layer,F_11(input_layer)]), F_13..]
                x = concatenate([x, F_dc], axis=3, name='RDB_Concat_%d_%d' % (d, c))
            # 1x1 convolution (Local Feature Fusion)
            x = Conv2D(
                64, kernel_size=1, kernel_initializer=initializer, name='LFF_%d' % (d)
            )(x)
            # Local Residual Learning F_{i,LF} + F_{i-1}
            rdb_in = Add(name='LRL_%d' % (d))([x, rdb_in])
            rdb_concat.append(rdb_in)
        
        assert len(rdb_concat) == 20
        
        return concatenate(rdb_concat, axis=3, name='LRLs_Concat')

# %%
initializer = RandomUniform( minval=-0.05, maxval=0.05, seed=None)

# %%
LR_input = Input(shape=(None, None, 3), name='LR')
F_m1 = Conv2D( 64,kernel_size=3,padding='same',kernel_initializer=initializer,name='F_m1',)(LR_input)
F_0 = Conv2D(64,kernel_size=3,padding='same',kernel_initializer=initializer,name='F_0',)(F_m1)
FD = _RDBs(F_0)
# Global Feature Fusion
# 1x1 Conv of concat RDB layers -> G0 feature maps
GFF1 = Conv2D(64,kernel_size=1,padding='same',kernel_initializer=initializer,name='GFF_1',)(FD)

GFF2 = Conv2D(64,kernel_size=3,padding='same',kernel_initializer=initializer,name='GFF_2',)(GFF1)
# Global Residual Learning for Dense Features
FDF = Add(name='FDF')([GFF2, F_m1])
# Upscaling
FU = _UPN(FDF)
# Compose SR image
SR = Conv2D(3,kernel_size=3,padding='same',kernel_initializer=initializer,name='SR',)(FU)
        
Model_RDN=Model(inputs=LR_input, outputs=SR)

# %%
Model_RDN.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# LR (InputLayer)                 [(None, None, None,  0
# __________________________________________________________________________________________________
# F_m1 (Conv2D)                   (None, None, None, 6 1792        LR[0][0]
# __________________________________________________________________________________________________
# F_0 (Conv2D)                    (None, None, None, 6 36928       F_m1[0][0]
# __________________________________________________________________________________________________
# F_1_1 (Conv2D)                  (None, None, None, 6 36928       F_0[0][0]
# __________________________________________________________________________________________________
# F_1_1_Relu (Activation)         (None, None, None, 6 0           F_1_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_1_1 (Concatenate)    (None, None, None, 1 0           F_0[0][0]
#                                                                  F_1_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_1_2 (Conv2D)                  (None, None, None, 6 73792       RDB_Concat_1_1[0][0]
# __________________________________________________________________________________________________
# F_1_2_Relu (Activation)         (None, None, None, 6 0           F_1_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_1_2 (Concatenate)    (None, None, None, 1 0           RDB_Concat_1_1[0][0]
#                                                                  F_1_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_1_3 (Conv2D)                  (None, None, None, 6 110656      RDB_Concat_1_2[0][0]
# __________________________________________________________________________________________________
# F_1_3_Relu (Activation)         (None, None, None, 6 0           F_1_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_1_3 (Concatenate)    (None, None, None, 2 0           RDB_Concat_1_2[0][0]
#                                                                  F_1_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_1_4 (Conv2D)                  (None, None, None, 6 147520      RDB_Concat_1_3[0][0]
# __________________________________________________________________________________________________
# F_1_4_Relu (Activation)         (None, None, None, 6 0           F_1_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_1_4 (Concatenate)    (None, None, None, 3 0           RDB_Concat_1_3[0][0]
#                                                                  F_1_4_Relu[0][0]
# __________________________________________________________________________________________________
# F_1_5 (Conv2D)                  (None, None, None, 6 184384      RDB_Concat_1_4[0][0]
# __________________________________________________________________________________________________
# F_1_5_Relu (Activation)         (None, None, None, 6 0           F_1_5[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_1_5 (Concatenate)    (None, None, None, 3 0           RDB_Concat_1_4[0][0]
#                                                                  F_1_5_Relu[0][0]
# __________________________________________________________________________________________________
# F_1_6 (Conv2D)                  (None, None, None, 6 221248      RDB_Concat_1_5[0][0]
# __________________________________________________________________________________________________
# F_1_6_Relu (Activation)         (None, None, None, 6 0           F_1_6[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_1_6 (Concatenate)    (None, None, None, 4 0           RDB_Concat_1_5[0][0]
#                                                                  F_1_6_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_1 (Conv2D)                  (None, None, None, 6 28736       RDB_Concat_1_6[0][0]
# __________________________________________________________________________________________________
# LRL_1 (Add)                     (None, None, None, 6 0           LFF_1[0][0]
#                                                                  F_0[0][0]
# __________________________________________________________________________________________________
# F_2_1 (Conv2D)                  (None, None, None, 6 36928       LRL_1[0][0]
# __________________________________________________________________________________________________
# F_2_1_Relu (Activation)         (None, None, None, 6 0           F_2_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_2_1 (Concatenate)    (None, None, None, 1 0           LRL_1[0][0]
#                                                                  F_2_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_2_2 (Conv2D)                  (None, None, None, 6 73792       RDB_Concat_2_1[0][0]
# __________________________________________________________________________________________________
# F_2_2_Relu (Activation)         (None, None, None, 6 0           F_2_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_2_2 (Concatenate)    (None, None, None, 1 0           RDB_Concat_2_1[0][0]
#                                                                  F_2_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_2_3 (Conv2D)                  (None, None, None, 6 110656      RDB_Concat_2_2[0][0]
# __________________________________________________________________________________________________
# F_2_3_Relu (Activation)         (None, None, None, 6 0           F_2_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_2_3 (Concatenate)    (None, None, None, 2 0           RDB_Concat_2_2[0][0]
#                                                                  F_2_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_2_4 (Conv2D)                  (None, None, None, 6 147520      RDB_Concat_2_3[0][0]
# __________________________________________________________________________________________________
# F_2_4_Relu (Activation)         (None, None, None, 6 0           F_2_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_2_4 (Concatenate)    (None, None, None, 3 0           RDB_Concat_2_3[0][0]
#                                                                  F_2_4_Relu[0][0]
# __________________________________________________________________________________________________
# F_2_5 (Conv2D)                  (None, None, None, 6 184384      RDB_Concat_2_4[0][0]
# __________________________________________________________________________________________________
# F_2_5_Relu (Activation)         (None, None, None, 6 0           F_2_5[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_2_5 (Concatenate)    (None, None, None, 3 0           RDB_Concat_2_4[0][0]
#                                                                  F_2_5_Relu[0][0]
# __________________________________________________________________________________________________
# F_2_6 (Conv2D)                  (None, None, None, 6 221248      RDB_Concat_2_5[0][0]
# __________________________________________________________________________________________________
# F_2_6_Relu (Activation)         (None, None, None, 6 0           F_2_6[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_2_6 (Concatenate)    (None, None, None, 4 0           RDB_Concat_2_5[0][0]
#                                                                  F_2_6_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_2 (Conv2D)                  (None, None, None, 6 28736       RDB_Concat_2_6[0][0]
# __________________________________________________________________________________________________
# LRL_2 (Add)                     (None, None, None, 6 0           LFF_2[0][0]
#                                                                  LRL_1[0][0]
# __________________________________________________________________________________________________
# F_3_1 (Conv2D)                  (None, None, None, 6 36928       LRL_2[0][0]
# __________________________________________________________________________________________________
# F_3_1_Relu (Activation)         (None, None, None, 6 0           F_3_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_3_1 (Concatenate)    (None, None, None, 1 0           LRL_2[0][0]
#                                                                  F_3_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_3_2 (Conv2D)                  (None, None, None, 6 73792       RDB_Concat_3_1[0][0]
# __________________________________________________________________________________________________
# F_3_2_Relu (Activation)         (None, None, None, 6 0           F_3_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_3_2 (Concatenate)    (None, None, None, 1 0           RDB_Concat_3_1[0][0]
#                                                                  F_3_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_3_3 (Conv2D)                  (None, None, None, 6 110656      RDB_Concat_3_2[0][0]
# __________________________________________________________________________________________________
# F_3_3_Relu (Activation)         (None, None, None, 6 0           F_3_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_3_3 (Concatenate)    (None, None, None, 2 0           RDB_Concat_3_2[0][0]
#                                                                  F_3_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_3_4 (Conv2D)                  (None, None, None, 6 147520      RDB_Concat_3_3[0][0]
# __________________________________________________________________________________________________
# F_3_4_Relu (Activation)         (None, None, None, 6 0           F_3_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_3_4 (Concatenate)    (None, None, None, 3 0           RDB_Concat_3_3[0][0]
#                                                                  F_3_4_Relu[0][0]
# __________________________________________________________________________________________________
# F_3_5 (Conv2D)                  (None, None, None, 6 184384      RDB_Concat_3_4[0][0]
# __________________________________________________________________________________________________
# F_3_5_Relu (Activation)         (None, None, None, 6 0           F_3_5[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_3_5 (Concatenate)    (None, None, None, 3 0           RDB_Concat_3_4[0][0]
#                                                                  F_3_5_Relu[0][0]
# __________________________________________________________________________________________________
# F_3_6 (Conv2D)                  (None, None, None, 6 221248      RDB_Concat_3_5[0][0]
# __________________________________________________________________________________________________
# F_3_6_Relu (Activation)         (None, None, None, 6 0           F_3_6[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_3_6 (Concatenate)    (None, None, None, 4 0           RDB_Concat_3_5[0][0]
#                                                                  F_3_6_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_3 (Conv2D)                  (None, None, None, 6 28736       RDB_Concat_3_6[0][0]
# __________________________________________________________________________________________________
# LRL_3 (Add)                     (None, None, None, 6 0           LFF_3[0][0]
#                                                                  LRL_2[0][0]
# __________________________________________________________________________________________________
# F_4_1 (Conv2D)                  (None, None, None, 6 36928       LRL_3[0][0]
# __________________________________________________________________________________________________
# F_4_1_Relu (Activation)         (None, None, None, 6 0           F_4_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_4_1 (Concatenate)    (None, None, None, 1 0           LRL_3[0][0]
#                                                                  F_4_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_4_2 (Conv2D)                  (None, None, None, 6 73792       RDB_Concat_4_1[0][0]
# __________________________________________________________________________________________________
# F_4_2_Relu (Activation)         (None, None, None, 6 0           F_4_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_4_2 (Concatenate)    (None, None, None, 1 0           RDB_Concat_4_1[0][0]
#                                                                  F_4_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_4_3 (Conv2D)                  (None, None, None, 6 110656      RDB_Concat_4_2[0][0]
# __________________________________________________________________________________________________
# F_4_3_Relu (Activation)         (None, None, None, 6 0           F_4_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_4_3 (Concatenate)    (None, None, None, 2 0           RDB_Concat_4_2[0][0]
#                                                                  F_4_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_4_4 (Conv2D)                  (None, None, None, 6 147520      RDB_Concat_4_3[0][0]
# __________________________________________________________________________________________________
# F_4_4_Relu (Activation)         (None, None, None, 6 0           F_4_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_4_4 (Concatenate)    (None, None, None, 3 0           RDB_Concat_4_3[0][0]
#                                                                  F_4_4_Relu[0][0]
# __________________________________________________________________________________________________
# F_4_5 (Conv2D)                  (None, None, None, 6 184384      RDB_Concat_4_4[0][0]
# __________________________________________________________________________________________________
# F_4_5_Relu (Activation)         (None, None, None, 6 0           F_4_5[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_4_5 (Concatenate)    (None, None, None, 3 0           RDB_Concat_4_4[0][0]
#                                                                  F_4_5_Relu[0][0]
# __________________________________________________________________________________________________
# F_4_6 (Conv2D)                  (None, None, None, 6 221248      RDB_Concat_4_5[0][0]
# __________________________________________________________________________________________________
# F_4_6_Relu (Activation)         (None, None, None, 6 0           F_4_6[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_4_6 (Concatenate)    (None, None, None, 4 0           RDB_Concat_4_5[0][0]
#                                                                  F_4_6_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_4 (Conv2D)                  (None, None, None, 6 28736       RDB_Concat_4_6[0][0]
# __________________________________________________________________________________________________
# LRL_4 (Add)                     (None, None, None, 6 0           LFF_4[0][0]
#                                                                  LRL_3[0][0]
# __________________________________________________________________________________________________
# F_5_1 (Conv2D)                  (None, None, None, 6 36928       LRL_4[0][0]
# __________________________________________________________________________________________________
# F_5_1_Relu (Activation)         (None, None, None, 6 0           F_5_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_5_1 (Concatenate)    (None, None, None, 1 0           LRL_4[0][0]
#                                                                  F_5_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_5_2 (Conv2D)                  (None, None, None, 6 73792       RDB_Concat_5_1[0][0]
# __________________________________________________________________________________________________
# F_5_2_Relu (Activation)         (None, None, None, 6 0           F_5_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_5_2 (Concatenate)    (None, None, None, 1 0           RDB_Concat_5_1[0][0]
#                                                                  F_5_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_5_3 (Conv2D)                  (None, None, None, 6 110656      RDB_Concat_5_2[0][0]
# __________________________________________________________________________________________________
# F_5_3_Relu (Activation)         (None, None, None, 6 0           F_5_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_5_3 (Concatenate)    (None, None, None, 2 0           RDB_Concat_5_2[0][0]
#                                                                  F_5_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_5_4 (Conv2D)                  (None, None, None, 6 147520      RDB_Concat_5_3[0][0]
# __________________________________________________________________________________________________
# F_5_4_Relu (Activation)         (None, None, None, 6 0           F_5_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_5_4 (Concatenate)    (None, None, None, 3 0           RDB_Concat_5_3[0][0]
#                                                                  F_5_4_Relu[0][0]
# __________________________________________________________________________________________________
# F_5_5 (Conv2D)                  (None, None, None, 6 184384      RDB_Concat_5_4[0][0]
# __________________________________________________________________________________________________
# F_5_5_Relu (Activation)         (None, None, None, 6 0           F_5_5[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_5_5 (Concatenate)    (None, None, None, 3 0           RDB_Concat_5_4[0][0]
#                                                                  F_5_5_Relu[0][0]
# __________________________________________________________________________________________________
# F_5_6 (Conv2D)                  (None, None, None, 6 221248      RDB_Concat_5_5[0][0]
# __________________________________________________________________________________________________
# F_5_6_Relu (Activation)         (None, None, None, 6 0           F_5_6[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_5_6 (Concatenate)    (None, None, None, 4 0           RDB_Concat_5_5[0][0]
#                                                                  F_5_6_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_5 (Conv2D)                  (None, None, None, 6 28736       RDB_Concat_5_6[0][0]
# __________________________________________________________________________________________________
# LRL_5 (Add)                     (None, None, None, 6 0           LFF_5[0][0]
#                                                                  LRL_4[0][0]
# __________________________________________________________________________________________________
# F_6_1 (Conv2D)                  (None, None, None, 6 36928       LRL_5[0][0]
# __________________________________________________________________________________________________
# F_6_1_Relu (Activation)         (None, None, None, 6 0           F_6_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_6_1 (Concatenate)    (None, None, None, 1 0           LRL_5[0][0]
#                                                                  F_6_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_6_2 (Conv2D)                  (None, None, None, 6 73792       RDB_Concat_6_1[0][0]
# __________________________________________________________________________________________________
# F_6_2_Relu (Activation)         (None, None, None, 6 0           F_6_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_6_2 (Concatenate)    (None, None, None, 1 0           RDB_Concat_6_1[0][0]
#                                                                  F_6_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_6_3 (Conv2D)                  (None, None, None, 6 110656      RDB_Concat_6_2[0][0]
# __________________________________________________________________________________________________
# F_6_3_Relu (Activation)         (None, None, None, 6 0           F_6_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_6_3 (Concatenate)    (None, None, None, 2 0           RDB_Concat_6_2[0][0]
#                                                                  F_6_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_6_4 (Conv2D)                  (None, None, None, 6 147520      RDB_Concat_6_3[0][0]
# __________________________________________________________________________________________________
# F_6_4_Relu (Activation)         (None, None, None, 6 0           F_6_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_6_4 (Concatenate)    (None, None, None, 3 0           RDB_Concat_6_3[0][0]
#                                                                  F_6_4_Relu[0][0]
# __________________________________________________________________________________________________
# F_6_5 (Conv2D)                  (None, None, None, 6 184384      RDB_Concat_6_4[0][0]
# __________________________________________________________________________________________________
# F_6_5_Relu (Activation)         (None, None, None, 6 0           F_6_5[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_6_5 (Concatenate)    (None, None, None, 3 0           RDB_Concat_6_4[0][0]
#                                                                  F_6_5_Relu[0][0]
# __________________________________________________________________________________________________
# F_6_6 (Conv2D)                  (None, None, None, 6 221248      RDB_Concat_6_5[0][0]
# __________________________________________________________________________________________________
# F_6_6_Relu (Activation)         (None, None, None, 6 0           F_6_6[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_6_6 (Concatenate)    (None, None, None, 4 0           RDB_Concat_6_5[0][0]
#                                                                  F_6_6_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_6 (Conv2D)                  (None, None, None, 6 28736       RDB_Concat_6_6[0][0]
# __________________________________________________________________________________________________
# LRL_6 (Add)                     (None, None, None, 6 0           LFF_6[0][0]
#                                                                  LRL_5[0][0]
# __________________________________________________________________________________________________
# F_7_1 (Conv2D)                  (None, None, None, 6 36928       LRL_6[0][0]
# __________________________________________________________________________________________________
# F_7_1_Relu (Activation)         (None, None, None, 6 0           F_7_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_7_1 (Concatenate)    (None, None, None, 1 0           LRL_6[0][0]
#                                                                  F_7_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_7_2 (Conv2D)                  (None, None, None, 6 73792       RDB_Concat_7_1[0][0]
# __________________________________________________________________________________________________
# F_7_2_Relu (Activation)         (None, None, None, 6 0           F_7_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_7_2 (Concatenate)    (None, None, None, 1 0           RDB_Concat_7_1[0][0]
#                                                                  F_7_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_7_3 (Conv2D)                  (None, None, None, 6 110656      RDB_Concat_7_2[0][0]
# __________________________________________________________________________________________________
# F_7_3_Relu (Activation)         (None, None, None, 6 0           F_7_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_7_3 (Concatenate)    (None, None, None, 2 0           RDB_Concat_7_2[0][0]
#                                                                  F_7_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_7_4 (Conv2D)                  (None, None, None, 6 147520      RDB_Concat_7_3[0][0]
# __________________________________________________________________________________________________
# F_7_4_Relu (Activation)         (None, None, None, 6 0           F_7_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_7_4 (Concatenate)    (None, None, None, 3 0           RDB_Concat_7_3[0][0]
#                                                                  F_7_4_Relu[0][0]
# __________________________________________________________________________________________________
# F_7_5 (Conv2D)                  (None, None, None, 6 184384      RDB_Concat_7_4[0][0]
# __________________________________________________________________________________________________
# F_7_5_Relu (Activation)         (None, None, None, 6 0           F_7_5[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_7_5 (Concatenate)    (None, None, None, 3 0           RDB_Concat_7_4[0][0]
#                                                                  F_7_5_Relu[0][0]
# __________________________________________________________________________________________________
# F_7_6 (Conv2D)                  (None, None, None, 6 221248      RDB_Concat_7_5[0][0]
# __________________________________________________________________________________________________
# F_7_6_Relu (Activation)         (None, None, None, 6 0           F_7_6[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_7_6 (Concatenate)    (None, None, None, 4 0           RDB_Concat_7_5[0][0]
#                                                                  F_7_6_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_7 (Conv2D)                  (None, None, None, 6 28736       RDB_Concat_7_6[0][0]
# __________________________________________________________________________________________________
# LRL_7 (Add)                     (None, None, None, 6 0           LFF_7[0][0]
#                                                                  LRL_6[0][0]
# __________________________________________________________________________________________________
# F_8_1 (Conv2D)                  (None, None, None, 6 36928       LRL_7[0][0]
# __________________________________________________________________________________________________
# F_8_1_Relu (Activation)         (None, None, None, 6 0           F_8_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_8_1 (Concatenate)    (None, None, None, 1 0           LRL_7[0][0]
#                                                                  F_8_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_8_2 (Conv2D)                  (None, None, None, 6 73792       RDB_Concat_8_1[0][0]
# __________________________________________________________________________________________________
# F_8_2_Relu (Activation)         (None, None, None, 6 0           F_8_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_8_2 (Concatenate)    (None, None, None, 1 0           RDB_Concat_8_1[0][0]
#                                                                  F_8_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_8_3 (Conv2D)                  (None, None, None, 6 110656      RDB_Concat_8_2[0][0]
# __________________________________________________________________________________________________
# F_8_3_Relu (Activation)         (None, None, None, 6 0           F_8_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_8_3 (Concatenate)    (None, None, None, 2 0           RDB_Concat_8_2[0][0]
#                                                                  F_8_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_8_4 (Conv2D)                  (None, None, None, 6 147520      RDB_Concat_8_3[0][0]
# __________________________________________________________________________________________________
# F_8_4_Relu (Activation)         (None, None, None, 6 0           F_8_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_8_4 (Concatenate)    (None, None, None, 3 0           RDB_Concat_8_3[0][0]
#                                                                  F_8_4_Relu[0][0]
# __________________________________________________________________________________________________
# F_8_5 (Conv2D)                  (None, None, None, 6 184384      RDB_Concat_8_4[0][0]
# __________________________________________________________________________________________________
# F_8_5_Relu (Activation)         (None, None, None, 6 0           F_8_5[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_8_5 (Concatenate)    (None, None, None, 3 0           RDB_Concat_8_4[0][0]
#                                                                  F_8_5_Relu[0][0]
# __________________________________________________________________________________________________
# F_8_6 (Conv2D)                  (None, None, None, 6 221248      RDB_Concat_8_5[0][0]
# __________________________________________________________________________________________________
# F_8_6_Relu (Activation)         (None, None, None, 6 0           F_8_6[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_8_6 (Concatenate)    (None, None, None, 4 0           RDB_Concat_8_5[0][0]
#                                                                  F_8_6_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_8 (Conv2D)                  (None, None, None, 6 28736       RDB_Concat_8_6[0][0]
# __________________________________________________________________________________________________
# LRL_8 (Add)                     (None, None, None, 6 0           LFF_8[0][0]
#                                                                  LRL_7[0][0]
# __________________________________________________________________________________________________
# F_9_1 (Conv2D)                  (None, None, None, 6 36928       LRL_8[0][0]
# __________________________________________________________________________________________________
# F_9_1_Relu (Activation)         (None, None, None, 6 0           F_9_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_9_1 (Concatenate)    (None, None, None, 1 0           LRL_8[0][0]
#                                                                  F_9_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_9_2 (Conv2D)                  (None, None, None, 6 73792       RDB_Concat_9_1[0][0]
# __________________________________________________________________________________________________
# F_9_2_Relu (Activation)         (None, None, None, 6 0           F_9_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_9_2 (Concatenate)    (None, None, None, 1 0           RDB_Concat_9_1[0][0]
#                                                                  F_9_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_9_3 (Conv2D)                  (None, None, None, 6 110656      RDB_Concat_9_2[0][0]
# __________________________________________________________________________________________________
# F_9_3_Relu (Activation)         (None, None, None, 6 0           F_9_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_9_3 (Concatenate)    (None, None, None, 2 0           RDB_Concat_9_2[0][0]
#                                                                  F_9_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_9_4 (Conv2D)                  (None, None, None, 6 147520      RDB_Concat_9_3[0][0]
# __________________________________________________________________________________________________
# F_9_4_Relu (Activation)         (None, None, None, 6 0           F_9_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_9_4 (Concatenate)    (None, None, None, 3 0           RDB_Concat_9_3[0][0]
#                                                                  F_9_4_Relu[0][0]
# __________________________________________________________________________________________________
# F_9_5 (Conv2D)                  (None, None, None, 6 184384      RDB_Concat_9_4[0][0]
# __________________________________________________________________________________________________
# F_9_5_Relu (Activation)         (None, None, None, 6 0           F_9_5[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_9_5 (Concatenate)    (None, None, None, 3 0           RDB_Concat_9_4[0][0]
#                                                                  F_9_5_Relu[0][0]
# __________________________________________________________________________________________________
# F_9_6 (Conv2D)                  (None, None, None, 6 221248      RDB_Concat_9_5[0][0]
# __________________________________________________________________________________________________
# F_9_6_Relu (Activation)         (None, None, None, 6 0           F_9_6[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_9_6 (Concatenate)    (None, None, None, 4 0           RDB_Concat_9_5[0][0]
#                                                                  F_9_6_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_9 (Conv2D)                  (None, None, None, 6 28736       RDB_Concat_9_6[0][0]
# __________________________________________________________________________________________________
# LRL_9 (Add)                     (None, None, None, 6 0           LFF_9[0][0]
#                                                                  LRL_8[0][0]
# __________________________________________________________________________________________________
# F_10_1 (Conv2D)                 (None, None, None, 6 36928       LRL_9[0][0]
# __________________________________________________________________________________________________
# F_10_1_Relu (Activation)        (None, None, None, 6 0           F_10_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_10_1 (Concatenate)   (None, None, None, 1 0           LRL_9[0][0]
#                                                                  F_10_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_10_2 (Conv2D)                 (None, None, None, 6 73792       RDB_Concat_10_1[0][0]
# __________________________________________________________________________________________________
# F_10_2_Relu (Activation)        (None, None, None, 6 0           F_10_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_10_2 (Concatenate)   (None, None, None, 1 0           RDB_Concat_10_1[0][0]
#                                                                  F_10_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_10_3 (Conv2D)                 (None, None, None, 6 110656      RDB_Concat_10_2[0][0]
# __________________________________________________________________________________________________
# F_10_3_Relu (Activation)        (None, None, None, 6 0           F_10_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_10_3 (Concatenate)   (None, None, None, 2 0           RDB_Concat_10_2[0][0]
#                                                                  F_10_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_10_4 (Conv2D)                 (None, None, None, 6 147520      RDB_Concat_10_3[0][0]
# __________________________________________________________________________________________________
# F_10_4_Relu (Activation)        (None, None, None, 6 0           F_10_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_10_4 (Concatenate)   (None, None, None, 3 0           RDB_Concat_10_3[0][0]
#                                                                  F_10_4_Relu[0][0]
# __________________________________________________________________________________________________
# F_10_5 (Conv2D)                 (None, None, None, 6 184384      RDB_Concat_10_4[0][0]
# __________________________________________________________________________________________________
# F_10_5_Relu (Activation)        (None, None, None, 6 0           F_10_5[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_10_5 (Concatenate)   (None, None, None, 3 0           RDB_Concat_10_4[0][0]
#                                                                  F_10_5_Relu[0][0]
# __________________________________________________________________________________________________
# F_10_6 (Conv2D)                 (None, None, None, 6 221248      RDB_Concat_10_5[0][0]
# __________________________________________________________________________________________________
# F_10_6_Relu (Activation)        (None, None, None, 6 0           F_10_6[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_10_6 (Concatenate)   (None, None, None, 4 0           RDB_Concat_10_5[0][0]
#                                                                  F_10_6_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_10 (Conv2D)                 (None, None, None, 6 28736       RDB_Concat_10_6[0][0]
# __________________________________________________________________________________________________
# LRL_10 (Add)                    (None, None, None, 6 0           LFF_10[0][0]
#                                                                  LRL_9[0][0]
# __________________________________________________________________________________________________
# F_11_1 (Conv2D)                 (None, None, None, 6 36928       LRL_10[0][0]
# __________________________________________________________________________________________________
# F_11_1_Relu (Activation)        (None, None, None, 6 0           F_11_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_11_1 (Concatenate)   (None, None, None, 1 0           LRL_10[0][0]
# ...
# __________________________________________________________________________________________________
# RDB_Concat_18_4 (Concatenate)   (None, None, None, 3 0           RDB_Concat_18_3[0][0]
#                                                                  F_18_4_Relu[0][0]
# __________________________________________________________________________________________________
# F_18_5 (Conv2D)                 (None, None, None, 6 184384      RDB_Concat_18_4[0][0]
# __________________________________________________________________________________________________
# F_18_5_Relu (Activation)        (None, None, None, 6 0           F_18_5[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_18_5 (Concatenate)   (None, None, None, 3 0           RDB_Concat_18_4[0][0]
#                                                                  F_18_5_Relu[0][0]
# __________________________________________________________________________________________________
# F_18_6 (Conv2D)                 (None, None, None, 6 221248      RDB_Concat_18_5[0][0]
# __________________________________________________________________________________________________
# F_18_6_Relu (Activation)        (None, None, None, 6 0           F_18_6[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_18_6 (Concatenate)   (None, None, None, 4 0           RDB_Concat_18_5[0][0]
#                                                                  F_18_6_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_18 (Conv2D)                 (None, None, None, 6 28736       RDB_Concat_18_6[0][0]
# __________________________________________________________________________________________________
# LRL_18 (Add)                    (None, None, None, 6 0           LFF_18[0][0]
#                                                                  LRL_17[0][0]
# __________________________________________________________________________________________________
# F_19_1 (Conv2D)                 (None, None, None, 6 36928       LRL_18[0][0]
# __________________________________________________________________________________________________
# F_19_1_Relu (Activation)        (None, None, None, 6 0           F_19_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_19_1 (Concatenate)   (None, None, None, 1 0           LRL_18[0][0]
#                                                                  F_19_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_19_2 (Conv2D)                 (None, None, None, 6 73792       RDB_Concat_19_1[0][0]
# __________________________________________________________________________________________________
# F_19_2_Relu (Activation)        (None, None, None, 6 0           F_19_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_19_2 (Concatenate)   (None, None, None, 1 0           RDB_Concat_19_1[0][0]
#                                                                  F_19_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_19_3 (Conv2D)                 (None, None, None, 6 110656      RDB_Concat_19_2[0][0]
# __________________________________________________________________________________________________
# F_19_3_Relu (Activation)        (None, None, None, 6 0           F_19_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_19_3 (Concatenate)   (None, None, None, 2 0           RDB_Concat_19_2[0][0]
#                                                                  F_19_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_19_4 (Conv2D)                 (None, None, None, 6 147520      RDB_Concat_19_3[0][0]
# __________________________________________________________________________________________________
# F_19_4_Relu (Activation)        (None, None, None, 6 0           F_19_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_19_4 (Concatenate)   (None, None, None, 3 0           RDB_Concat_19_3[0][0]
#                                                                  F_19_4_Relu[0][0]
# __________________________________________________________________________________________________
# F_19_5 (Conv2D)                 (None, None, None, 6 184384      RDB_Concat_19_4[0][0]
# __________________________________________________________________________________________________
# F_19_5_Relu (Activation)        (None, None, None, 6 0           F_19_5[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_19_5 (Concatenate)   (None, None, None, 3 0           RDB_Concat_19_4[0][0]
#                                                                  F_19_5_Relu[0][0]
# __________________________________________________________________________________________________
# F_19_6 (Conv2D)                 (None, None, None, 6 221248      RDB_Concat_19_5[0][0]
# __________________________________________________________________________________________________
# F_19_6_Relu (Activation)        (None, None, None, 6 0           F_19_6[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_19_6 (Concatenate)   (None, None, None, 4 0           RDB_Concat_19_5[0][0]
#                                                                  F_19_6_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_19 (Conv2D)                 (None, None, None, 6 28736       RDB_Concat_19_6[0][0]
# __________________________________________________________________________________________________
# LRL_19 (Add)                    (None, None, None, 6 0           LFF_19[0][0]
#                                                                  LRL_18[0][0]
# __________________________________________________________________________________________________
# F_20_1 (Conv2D)                 (None, None, None, 6 36928       LRL_19[0][0]
# __________________________________________________________________________________________________
# F_20_1_Relu (Activation)        (None, None, None, 6 0           F_20_1[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_20_1 (Concatenate)   (None, None, None, 1 0           LRL_19[0][0]
#                                                                  F_20_1_Relu[0][0]
# __________________________________________________________________________________________________
# F_20_2 (Conv2D)                 (None, None, None, 6 73792       RDB_Concat_20_1[0][0]
# __________________________________________________________________________________________________
# F_20_2_Relu (Activation)        (None, None, None, 6 0           F_20_2[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_20_2 (Concatenate)   (None, None, None, 1 0           RDB_Concat_20_1[0][0]
#                                                                  F_20_2_Relu[0][0]
# __________________________________________________________________________________________________
# F_20_3 (Conv2D)                 (None, None, None, 6 110656      RDB_Concat_20_2[0][0]
# __________________________________________________________________________________________________
# F_20_3_Relu (Activation)        (None, None, None, 6 0           F_20_3[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_20_3 (Concatenate)   (None, None, None, 2 0           RDB_Concat_20_2[0][0]
#                                                                  F_20_3_Relu[0][0]
# __________________________________________________________________________________________________
# F_20_4 (Conv2D)                 (None, None, None, 6 147520      RDB_Concat_20_3[0][0]
# __________________________________________________________________________________________________
# F_20_4_Relu (Activation)        (None, None, None, 6 0           F_20_4[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_20_4 (Concatenate)   (None, None, None, 3 0           RDB_Concat_20_3[0][0]
#                                                                  F_20_4_Relu[0][0]
# __________________________________________________________________________________________________
# F_20_5 (Conv2D)                 (None, None, None, 6 184384      RDB_Concat_20_4[0][0]
# __________________________________________________________________________________________________
# F_20_5_Relu (Activation)        (None, None, None, 6 0           F_20_5[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_20_5 (Concatenate)   (None, None, None, 3 0           RDB_Concat_20_4[0][0]
#                                                                  F_20_5_Relu[0][0]
# __________________________________________________________________________________________________
# F_20_6 (Conv2D)                 (None, None, None, 6 221248      RDB_Concat_20_5[0][0]
# __________________________________________________________________________________________________
# F_20_6_Relu (Activation)        (None, None, None, 6 0           F_20_6[0][0]
# __________________________________________________________________________________________________
# RDB_Concat_20_6 (Concatenate)   (None, None, None, 4 0           RDB_Concat_20_5[0][0]
#                                                                  F_20_6_Relu[0][0]
# __________________________________________________________________________________________________
# LFF_20 (Conv2D)                 (None, None, None, 6 28736       RDB_Concat_20_6[0][0]
# __________________________________________________________________________________________________
# LRL_20 (Add)                    (None, None, None, 6 0           LFF_20[0][0]
#                                                                  LRL_19[0][0]
# __________________________________________________________________________________________________
# LRLs_Concat (Concatenate)       (None, None, None, 1 0           LRL_1[0][0]
#                                                                  LRL_2[0][0]
#                                                                  LRL_3[0][0]
#                                                                  LRL_4[0][0]
#                                                                  LRL_5[0][0]
#                                                                  LRL_6[0][0]
#                                                                  LRL_7[0][0]
#                                                                  LRL_8[0][0]
#                                                                  LRL_9[0][0]
#                                                                  LRL_10[0][0]
#                                                                  LRL_11[0][0]
#                                                                  LRL_12[0][0]
#                                                                  LRL_13[0][0]
#                                                                  LRL_14[0][0]
#                                                                  LRL_15[0][0]
#                                                                  LRL_16[0][0]
#                                                                  LRL_17[0][0]
#                                                                  LRL_18[0][0]
#                                                                  LRL_19[0][0]
#                                                                  LRL_20[0][0]
# __________________________________________________________________________________________________
# GFF_1 (Conv2D)                  (None, None, None, 6 81984       LRLs_Concat[0][0]
# __________________________________________________________________________________________________
# GFF_2 (Conv2D)                  (None, None, None, 6 36928       GFF_1[0][0]
# __________________________________________________________________________________________________
# FDF (Add)                       (None, None, None, 6 0           GFF_2[0][0]
#                                                                  F_m1[0][0]
# __________________________________________________________________________________________________
# UPN1 (Conv2D)                   (None, None, None, 6 102464      FDF[0][0]
# __________________________________________________________________________________________________
# UPN1_Relu (Activation)          (None, None, None, 6 0           UPN1[0][0]
# __________________________________________________________________________________________________
# UPN2 (Conv2D)                   (None, None, None, 3 18464       UPN1_Relu[0][0]
# __________________________________________________________________________________________________
# UPN2_Relu (Activation)          (None, None, None, 3 0           UPN2[0][0]
# __________________________________________________________________________________________________
# UPN3 (Conv2D)                   (None, None, None, 4 13872       UPN2_Relu[0][0]
# __________________________________________________________________________________________________
# PixelShuffle (Lambda)           (None, None, None, 3 0           UPN3[0][0]
# __________________________________________________________________________________________________
# SR (Conv2D)                     (None, None, None, 3 84          PixelShuffle[0][0]
# ==================================================================================================
# Total params: 16,357,796
# Trainable params: 16,357,796
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
Model_RDN.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics='accuracy')

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=10,restore_best_weights=True)

# %%
history=Model_RDN.fit(train_dataset,epochs=100,batch_size=10,steps_per_epoch=72,validation_data=valid_dataset,
              validation_steps=18,callbacks=[callback])
# Out:
# 2022-06-22 21:30:36.433080: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-06-22 21:30:36.452266: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2499995000 Hz
# Epoch 1/100
# 2022-06-22 21:30:43.678197: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-06-22 21:30:45.457689: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2022-06-22 21:30:45.522922: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2022-06-22 21:30:46.254916: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 72/72 [==============================] - 104s 945ms/step - loss: 5744.5272 - accuracy: 0.3301 - val_loss: 0.0332 - val_accuracy: 0.4264
# Epoch 2/100
# 72/72 [==============================] - 69s 956ms/step - loss: 0.0308 - accuracy: 0.4147 - val_loss: 0.0272 - val_accuracy: 0.4184
# Epoch 3/100
# 72/72 [==============================] - 70s 970ms/step - loss: 0.0254 - accuracy: 0.4248 - val_loss: 0.0196 - val_accuracy: 0.4335
# Epoch 4/100
# 72/72 [==============================] - 71s 987ms/step - loss: 0.0212 - accuracy: 0.4122 - val_loss: 0.0197 - val_accuracy: 0.4931
# 72/72 [==============================] - 71s 985ms/step - loss: 0.0052 - accuracy: 0.8128 - val_loss: 0.0044 - val_accuracy: 0.8044
# Epoch 45/100
# 72/72 [==============================] - 70s 971ms/step - loss: 0.0047 - accuracy: 0.8431 - val_loss: 0.0045 - val_accuracy: 0.8123
# Epoch 46/100
# 72/72 [==============================] - 71s 985ms/step - loss: 0.0049 - accuracy: 0.8163 - val_loss: 0.0045 - val_accuracy: 0.8150
# Epoch 47/100
# 72/72 [==============================] - 71s 982ms/step - loss: 0.0048 - accuracy: 0.8136 - val_loss: 0.0049 - val_accuracy: 0.8241
# Epoch 48/100
# 72/72 [==============================] - 71s 991ms/step - loss: 0.0051 - accuracy: 0.8124 - val_loss: 0.0053 - val_accuracy: 0.7585
# Epoch 49/100
# 72/72 [==============================] - 70s 974ms/step - loss: 0.0048 - accuracy: 0.8124 - val_loss: 0.0045 - val_accuracy: 0.8028
# Epoch 50/100
# 72/72 [==============================] - 71s 985ms/step - loss: 0.0050 - accuracy: 0.8118 - val_loss: 0.0043 - val_accuracy: 0.7756

# %%
Model_RDN.save('RDN50_4x.h5')

# %%
import matplotlib.pyplot as plt

# %%
loss=history.history["loss"]
val_loss=history.history["val_loss"]
epochs=range(1,len(loss)+1)
plt.plot(epochs,loss,'y',label="training loss")
plt.plot(epochs,val_loss,'r',label="validation loss")
plt.title("training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
acc=history.history["accuracy"]
val_acc=history.history["val_accuracy"]
epochs=range(1,len(loss)+1)
plt.plot(epochs,acc,'y',label="training acc")
plt.plot(epochs,val_acc,'r',label="validation acc")
plt.title("training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
plt.legend()
plt.show()

# %%
print(history.history)
# Out:
# {'loss': [1.143545389175415, 0.039181556552648544, 0.026184765622019768, 0.019485026597976685, 0.020394589751958847, 0.016139376908540726, 0.014419084414839745, 0.009573547169566154, 0.008269475772976875, 0.00774100236594677, 0.007142333313822746, 0.007465492933988571, 0.00621396629139781, 0.005557700525969267, 0.0053597670048475266, 0.005116801708936691, 0.00519446050748229, 0.0045898426324129105, 0.0042161461897194386, 0.004692824557423592, 0.004768889397382736, 0.003938605543226004, 0.0046768514439463615, 0.004241384100168943, 0.003217921359464526, 0.0027571299578994513, 0.0028925505466759205, 0.0025556364562362432, 0.00232875719666481, 0.0021640330087393522, 0.0020254813134670258, 0.002214334439486265, 0.0020808347035199404, 0.0021900308784097433, 0.0019067518878728151, 0.002463625045493245, 0.0022262188140302896, 0.0017753839492797852, 0.0019831445533782244, 0.0018962717149406672, 0.0019397513242438436, 0.0019565243273973465, 0.001684758928604424, 0.0016949651762843132, 0.0017741319024935365, 0.0015586253721266985, 0.0016021174378693104, 0.002775428583845496, 0.002755315974354744, 0.0016485184896737337, 0.0017363016959279776, 0.0014850300503894687, 0.0014983302680775523, 0.0014944279100745916, 0.0014517651870846748, 0.0016268243780359626, 0.0018238755874335766, 0.0027146749198436737, 0.0016392860561609268, 0.0015761317918077111, 0.0014428769936785102, 0.001349681755527854, 0.0013867189409211278, 0.0016098725609481335, 0.0015393919311463833, 0.001277188421227038, 0.0014622247545048594, 0.0013207492884248495, 0.0013556669000536203, 